# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\DELL\Downloads\StudentsPerformance.csv")

# %%
datac=data.copy()

# %%
datac
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
datac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
datac.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
datac.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
datac.duplicated().sum()
# Out:
# 0

# %%
datac.shape
# Out:
# (1000, 8)

# %%
datac.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
datac.groupby(['gender','lunch'])[['math score', 'reading score', 'writing score']].mean()
# Out:
#                      math score  reading score  writing score
# gender lunch
# female free/reduced   55.814815      67.386243      66.444444
#        standard       68.124620      75.607903      75.927052
# male   free/reduced   62.457831      61.542169      59.126506
#        standard       72.022152      67.537975      65.509494

# %%
datac.groupby('gender')[['math score', 'reading score', 'writing score']].mean()
# Out:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
datac.groupby('race/ethnicity')[['math score', 'reading score', 'writing score']].mean()
# Out:
#                 math score  reading score  writing score
# race/ethnicity
# group A          61.629213      64.674157      62.674157
# group B          63.452632      67.352632      65.600000
# group C          64.463950      69.103448      67.827586
# group D          67.362595      70.030534      70.145038
# group E          73.821429      73.028571      71.407143

# %%
datac.groupby('lunch')[['math score', 'reading score', 'writing score']].mean()
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced   58.921127      64.653521      63.022535
# standard       70.034109      71.654264      70.823256

# %%
datac.groupby('parental level of education')[['math score', 'reading score', 'writing score']].mean()
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %%
datac.groupby('test preparation course')[['math score', 'reading score', 'writing score']].mean()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 69.695531      73.893855      74.418994
# none                      64.077882      66.534268      64.504673

# %%
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)

# %%
Grouped_data=datac.groupby(['gender','lunch','test preparation course','parental level of education','race/ethnicity'])[['math score', 'reading score', 'writing score']].mean()

# %%
print(Grouped_data)
# Out:
#                                                                                         math score  \
# gender lunch        test preparation course parental level of education race/ethnicity
# female free/reduced completed               associate's degree          group B          72.000000
#                                                                         group C          68.666667
#                                                                         group D          65.000000
#                                                                         group E          70.000000
#                                             bachelor's degree           group C          57.833333
#                                                                         group D          93.000000
#                                                                         group E          92.000000
# ...

# %%
datac['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
datac['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
datac['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
datac['average score']=datac[['math score', 'reading score','writing score']].mean(axis=1)

# %%
datac['average score']
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Name: average score, Length: 1000, dtype: float64

# %%
datac['performance_level'] = pd.cut(datac['average score'], bins=[0,60,80,100], labels=['Low','Medium','High'])

# %%
datac.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    average score performance_level
# 0      72.666667            Medium
# 1      82.333333              High
# 2      92.666667              High
# ...

# %%
datac['performance_level'].value_counts()
# Out:
# Medium    513
# Low       293
# High      194
# Name: performance_level, dtype: int64

# %%
datac['performance_level']
# Out:
# 0      Medium
# 1        High
# 2        High
# 3         Low
# 4      Medium
#         ...
# 995      High
# 996       Low
# 997    Medium
# 998    Medium
# 999      High
# Name: performance_level, Length: 1000, dtype: category
# Categories (3, object): ['Low' < 'Medium' < 'High']

# %%
plt.pie(x=datac["gender"].value_counts().values,labels=datac["gender"].value_counts().index,autopct="%0.2f%%",radius=1) 
plt.show()

# %%
pip install squarify
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import squarify

# %%
sns.histplot(datac['math score'], kde=True)
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
sns.boxplot(x='gender', y='reading score', data=datac)
# Out:
# <Axes: xlabel='gender', ylabel='reading score'>

# %%
sns.barplot(x='gender', y='math score', data=datac)
# Out:
# <Axes: xlabel='gender', ylabel='math score'>

# %%
sns.violinplot(x='test preparation course', y='writing score', data=datac)
# Out:
# <Axes: xlabel='test preparation course', ylabel='writing score'>

# %%
datac.corr()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4808\2923668630.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datac.corr()
#                math score  reading score  writing score  average score
# math score       1.000000       0.817580       0.802642       0.918746
# reading score    0.817580       1.000000       0.954598       0.970331
# writing score    0.802642       0.954598       1.000000       0.965667
# average score    0.918746       0.970331       0.965667       1.000000

# %%
# pair plot 
sns.pairplot(data=datac)

# %%
# math score

# %%
p = sns.countplot(x="math score", data = datac, palette="muted")
_ = plt.setp(p.get_xticklabels(), rotation=20)

# %%
plt.figure(figsize=(16,6))  # Adjust the figure size to avoid label overlap

p = sns.countplot(x="math score", data=datac, palette="muted")
p.set_xticklabels(p.get_xticklabels(), rotation=90)  # Rotate labels for better visibility

plt.tight_layout()  # Auto-adjust layout to fit everything
plt.show()

# %%
passmark=35
datac['Math_PassStatus'] = np.where(datac['math score']<passmark, 'F', 'P')
datac.Math_PassStatus.value_counts()
# Out:
# P    978
# F     22
# Name: Math_PassStatus, dtype: int64

# %%
p = sns.countplot(x='parental level of education', data = datac, hue='Math_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=25)

# %%
plt.figure(figsize=(16,6)) 
sns.countplot(x="reading score", data = datac, palette="muted")
plt.tight_layout()  # Auto-adjust layout to fit everything
plt.show()

# %%
datac['Reading_PassStatus'] = np.where(datac['reading score']<passmark, 'F', 'P')
datac.Reading_PassStatus.value_counts()
# Out:
# P    985
# F     15
# Name: Reading_PassStatus, dtype: int64

# %%
p = sns.countplot(x='parental level of education', data = datac, hue='Reading_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=20)

# %%
plt.figure(figsize=(16,6)) 
sns.countplot(x="writing score", data = datac, palette="muted")
plt.tight_layout()  # Auto-adjust layout to fit everything
plt.show()

# %%
datac['Writing_PassStatus'] = np.where(datac['writing score']<passmark, 'F', 'P')
datac.Writing_PassStatus.value_counts()
# Out:
# P    983
# F     17
# Name: Writing_PassStatus, dtype: int64

# %%
p = sns.countplot(x='parental level of education', data = datac, hue='Writing_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=25)

# %%
datac['OverAll_PassStatus'] = datac.apply(lambda x : 'F' if x['Math_PassStatus'] == 'F' or 
                                    x['Reading_PassStatus'] == 'F' or x['Writing_PassStatus'] == 'F' else 'P', axis =1)

datac.OverAll_PassStatus.value_counts()
# Out:
# P    971
# F     29
# Name: OverAll_PassStatus, dtype: int64

# %%
p = sns.countplot(x='parental level of education', data = datac, hue='OverAll_PassStatus', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=20)

# %%
datac['Total_Marks'] = datac['math score']+datac['reading score']+datac['writing score']
datac['Percentage'] = datac['Total_Marks']/3

# %%
plt.figure(figsize=(16,6))
p = sns.countplot(x="Percentage", data = datac, palette="muted")
_ = plt.setp(p.get_xticklabels(), rotation=0) 
plt.tight_layout()
plt.show()

# %%
def GetGrade(Percentage, OverAll_PassStatus):
    if ( OverAll_PassStatus == 'F'):
        return 'F'    
    if ( Percentage >= 80 ):
        return 'A'
    if ( Percentage >= 70):
        return 'B'
    if ( Percentage >= 60):
        return 'C'
    if ( Percentage >= 50):
        return 'D'
    if ( Percentage >= 40):
        return 'E'
    else: 
        return 'F'

datac['Grade'] = datac.apply(lambda x : GetGrade(x['Percentage'], x['OverAll_PassStatus']), axis=1)

datac.Grade.value_counts()
# Out:
# B    261
# C    256
# A    198
# D    182
# E     71
# F     32
# Name: Grade, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.set_context("talk",font_scale=1)
sns.set_palette("pastel")
ax = sns.countplot(y="Grade", hue="gender", data=datac, order=["A","B","C","D","E","F"])
ax.legend(loc='upper right',frameon=True)
plt.title('Gender vs Grades', fontsize=18, fontweight='bold')
ax.set(xlabel='COUNT',ylabel='GRADE')
plt.show()

# %%
sns.countplot(x="Grade", data = datac, order=['A','B','C','D','E','F'],  palette="muted")
plt.show()

# %%
p = sns.countplot(x='parental level of education', data = datac, hue='Grade', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
sns.set_context("paper",font_scale=1)
sns.kdeplot(data=datac,shade = True)
plt.xlabel('Score')
plt.title('Score Kde Plot', fontsize=15, fontweight='bold')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4808\482047823.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=datac,shade = True)

# %%
datac
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...
